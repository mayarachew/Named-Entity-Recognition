# %% [markdown]
# # Extract .zip files

# %%
# Unzip train dataset
# !unzip '../data/input/IOB' -d '../data/input/IOB'
# Out:
# Archive:  ../data/input/IOB.zip
#    creating: ../data/input/IOB/Layout1/
#   inflating: ../data/input/IOB/Layout1/1131GVDTD.csv
#   inflating: ../data/input/IOB/Layout1/1141GVDTD.csv
#   inflating: ../data/input/IOB/Layout1/1221GVDTD.csv
#   inflating: ../data/input/IOB/Layout1/1231GVDTD.csv
#   inflating: ../data/input/IOB/Layout1/1241GVDTD.csv
#   inflating: ../data/input/IOB/Layout1/1251GVDTD.csv
#   inflating: ../data/input/IOB/Layout1/1781GVDTD.csv
#   inflating: ../data/input/IOB/Layout1/1841GVDTD.csv
#   inflating: ../data/input/IOB/Layout1/1911GVDTD.csv
#   inflating: ../data/input/IOB/Layout1/1931GVDTD.csv
#   inflating: ../data/input/IOB/Layout1/1941GVDTD.csv
#   inflating: ../data/input/IOB/Layout1/2011GVDTD.csv
#   inflating: ../data/input/IOB/Layout1/2081GVDTD.csv
#   inflating: ../data/input/IOB/Layout1/2091GVDTD.csv
#   inflating: ../data/input/IOB/Layout1/2101GVDTD.csv
#   inflating: ../data/input/IOB/Layout1/2191GVDTD.csv
# ...
