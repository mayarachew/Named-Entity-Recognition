# %% [markdown]
# ## Apply best model on test (submit) data

# %% [markdown]
# ## Import

# %%
import pytesseract
import cv2
import os
import ntpath
import pandas as pd
import json

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

from functions.add_to_file import add_to_file

# %% [markdown]
# ## Read and transform train data

# %%
# Unzip train dataset
# !unzip '../data/train/0325updated.task2train(626p)-20220330T115700Z-001' -d '../data/train/train_dataset'
# Out:
# Archive:  ../data/train/0325updated.task2train(626p)-20220330T115700Z-001.zip
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164998.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114321.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164996.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099085.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51009453801.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099083.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123447.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008030565.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008042778.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099087.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008128065.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008128062.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008122920.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123604.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164999.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123446.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008030566.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123599.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164997.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099084.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008128052.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008042782.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008042777.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099081.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114284.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339114.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006387951.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006556828.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006329395.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006388044.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006332575.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006556830.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005711404.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339117.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339112.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006328920.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006332575.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006387971.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006556825.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006556831.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006332649.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006329399.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006387953.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006329402.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006329402.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005711403.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339115.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006556824.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006387932.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339113.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006329399.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005711441.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005705804.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005677328.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005676546.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005676545.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005711404.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006329395.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005676546.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005676547.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005676549.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005711403.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005677328.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005663277.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005711401.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005711401.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005663277.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005663280.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005663279.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005663276.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005663280.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005663278.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005676549.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005663279.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005676547.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164996(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164999(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164998(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164997(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005453801.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164998.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51009453804.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51009453801(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164997.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005453729.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005453801.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447853.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005453802.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447860.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447861.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164969.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164999.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164525.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447860.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447861.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51009453801.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005453729.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164996.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51009453804.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164992.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164524.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164510.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008145450.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008145504.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164991.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164969.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142068.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164992.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008145505.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142063.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164510.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008145505.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142063.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164524.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142065.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164420.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142062.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142065.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142068.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008145504.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164991.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008145450.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164525.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008164420.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142062.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142034.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142058.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142033.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142060.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142038.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142061.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142005.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142034.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142058.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142030.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142031.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142038.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142033.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142031.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142059.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008128062.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142061.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142059.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008128065.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008128052.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142032.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142030.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142032.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142005.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008142060.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123604(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123599(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008122920(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008128062(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114321(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008128065(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123447(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114321.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123450.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123586.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123446.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123446(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008128052(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123580.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123451.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123599.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123586.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123451.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123604.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123580.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123476.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123450.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123447.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008122920.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114281.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114216.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114283.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114284(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099084.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114262.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114283.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099102.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099085.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099089.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114260.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114282.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114282.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008123476.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114281.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114216.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114260.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099089.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099102.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099087.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114266.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114266.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114262.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114217.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114284.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008114217.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099084(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099081(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099087(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099083(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099081.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099054.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099085(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099049.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099046.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099073.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099083.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099071.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099048.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099041.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099054.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099043.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099046.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099043.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099048.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099044.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099041.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099049.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099044.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099073.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008099071.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008042778(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008030565(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008030566(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008042791.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008042793.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008042793.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008042778.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008063849.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008042782.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008042791.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008030566.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846395.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008042792.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008042792.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008042783.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008064061.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008064061.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008042783.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008042782(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008042777(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008030560.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008063849.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846393.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008042777.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008030565.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846451.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846368.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846305.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846269.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846370.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846307.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846325.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846398.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846302.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846357.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846353.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846309.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846412.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846391.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846410.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846270.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846388.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846286.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846326.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846350.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007843145.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846366.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007846301.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339653.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339642.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339166.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339651.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339650.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007579726.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339650(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339648.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339647(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339648(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339647.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339643.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339653.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339639.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339653(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339639.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339167.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339166.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339651.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339167.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339650.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339647.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339648.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339642.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339651(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339653(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339166(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339166(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339642(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339167(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339643(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339658.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007419197.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339657.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339656.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339639(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007419197.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339164.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007391372.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339157.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339164.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339656.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339657.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339658.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339158.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007391372.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339162.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339165.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339642(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339164(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339643(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339158(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339158(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339167(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339639(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339157(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339158.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339157.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339157(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339166(2).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339643(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339150.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339639(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339156.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339152.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339151.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339642(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339165(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339162.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339162(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339165.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339146.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51008030560.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339139.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339156.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339132.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339133.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339118.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339132.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339152.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339120.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339136.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007579726.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339146.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339135.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339136.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339150.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339126.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339133.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339139.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339118.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339126.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339130.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339135.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339643.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339120.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339130.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339131.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339151.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339166(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339112(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339100.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339117(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339110.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339115.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339111.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339114(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339117.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339113(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339167(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339112(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339107.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339113(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339114.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339112.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339113.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339111.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339107.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339117(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339100.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339131.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339110.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339106.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339115(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339115(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339106.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339114(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339100(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339110(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339107(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007225417.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339111(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339098.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007225417.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339097.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007225442.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007231336.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007231336.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339097.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339095.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007228448.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007225442.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007231338.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007262330.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339098.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007231338.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339113(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339106(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339095.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007228448.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339112(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339094.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007225442(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007231336(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007231338(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007225442(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007228448(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007225417(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007262328.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007231338(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007225417(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007231336(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007231370.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007339094.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007262315.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007231374.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007228448(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007231365.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007135247.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007262330.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007231361.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103702.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007231344.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007225399.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007231344.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007262315.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007262328.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007225398.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007135247.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103688.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007225399.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007135037.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007135037.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103691.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103692.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103599.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103675.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103688.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103641.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103702.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103643.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103681.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103641.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103578.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007225398.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103643.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103691.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103675.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103692.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103639.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103681.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103639.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006913031.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006913073.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006913007.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006913023.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103599.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006913051.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006913055.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51007103578.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006912974.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006913024.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006912972.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006913054.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006912960.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006913074.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006882603.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006867435.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006867436.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006913068.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006913070.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006913059.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006882603.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006913028.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006857660.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006913019.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006733494.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006733494.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006679216.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006714065.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006679222.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006620191.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006714065.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006828217.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006679216.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006647932.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006857660.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006713996.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006856981.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006679222.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006867436.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006713996.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006857071.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006857265.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006867435.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006857265.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006857071.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006856981.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006620414.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006620414.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006620189.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006647932.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006620190.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006620186.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006620181.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006620176.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006620187.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006619854.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006620190.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006619780.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006620161.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006620176.txt
# ...
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005301667(2).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005453801(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005453801(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447860(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005453729(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447861(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005453802(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447861(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005306399(3).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006414633.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447860(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006414631.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006414485.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006414533.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006414519.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006414599.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005453729(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447848.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005444045.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442394.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447832.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447840.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447833.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447850.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005444033.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447853.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005444037.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447833.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447832.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447853(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447839.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447852.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005444045.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447840.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442386.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005444037.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447850.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447852.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442397.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447848.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442386.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005444033.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442338.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442384.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442384.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442383.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442341.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442346.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442394.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442392.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442338.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442344.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442392.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442376.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442379.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442361.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442378.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442346.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442341.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442376.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442383.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442379.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442378.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442361.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005337872(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361895(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361883(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361900.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361897(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361883(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005365179.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361950.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361946.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442333.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361898(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005306399(4).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361897(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361907.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361907.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361898(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006414429.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006414394.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006414431.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006414483.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361950.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005337872(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361900.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006414470.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005433492.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005441401.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442327.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005441402.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005441402.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005441401.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442333.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005441408.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005433541.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005441408.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005433553.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005433538.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005433522.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005441407.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005433541.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005365179.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005441398.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005806679.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005433553.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005441398.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005433552.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361895(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442344.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442327.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005442397.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005447839.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361900(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361946(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005306399(5).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005301667(4).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361895(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361898(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361950(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005433514.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005433492(1).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361907(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005337872(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361883(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005433533.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005433538.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005433494.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005433522.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005433492.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005433514.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005441407.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361900(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005306399(4).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005303661(4).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005433494.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361897(2).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005433533.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005365179(1).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005301659(4).jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005268262.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005301661(4).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005303661(4).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005268200.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005255805.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X00016469676.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005268262.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005200938.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X00016469676.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005255805.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005268400.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005268472.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X00016469669.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005268472.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005230617.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X00016469669.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005200938.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005806678.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005268400.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005230617.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X00016469623.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X00016469622.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X00016469623.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X00016469612.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X00016469619.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X00016469620.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X00016469622.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X00016469619.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005361946.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X00016469672.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X00016469612.txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005268200.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X00016469672.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X00016469620.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51006414392.jpg
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005301659(4).txt
#   inflating: ../data/train/train_dataset/0325updated.task2train(626p)/X51005433552.txt

# %%
train_dataset_path = '../data/train/train_dataset/0325updated.task2train(626p)'

train_corpus = pd.DataFrame()

id_list = []
text_list = []
company_list = []
date_list = []
address_list = []
total_list = []

for filename in os.listdir(train_dataset_path):
    # If its a text (.txt)
    if '.txt' in filename:
        id = filename.replace('.txt','').replace('(1)','')
        id_list.append(id)

        f = open(train_dataset_path+'/'+filename)
        data = json.load(f)
        company_list.append(data.get('company'))
        date_list.append(data.get('date'))
        address_list.append(data.get('address'))
        total_list.append(data.get('total'))

train_corpus['id'] = id_list
train_corpus['company'] = company_list
train_corpus['date'] = date_list
train_corpus['address'] = address_list
train_corpus['total'] = total_list

# %%
train_corpus.head()
# Out:
#              id                           company         date  \
# 0  X51006913007                  AEON CO. (M) BHD   27/05/2018
# 1  X51005705722    ASO ELECTRICAL TRADING SDN BHD   27/09/2017
# 2  X51005763940       ELITETRAX MARKETING SDN BHD     11.02.18
# 3  X51008099071  LEONG HENG SHELL SERVICE STATION     20/06/18
# 4  X51005757349                  GOLDEN KEY MAKER  24-MAR-2018
#
#                                              address   total
# 0  3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMA...   99.90
# 1  NO 31G, JALAN SEPADU C 25/C, SECTION 25, TAMAN...  248.05
# 2  LOT 1F-01&02,1ST FLR,PARADIGM MALL, NO. 1 JALA...   60.00
# 3  LOT 26151 BANDAR SG LONG, 11 1/4 MILES CHERAS,...   50.00
# 4  NO 5, JALAN KENARI 2, BANDAR PUCHONG JAYA, 471...   21.00

# %%
for filename in os.listdir(train_dataset_path):
    # If its an image (.jpg)
    if '.jpg' in filename:
        id = filename.replace('.jpg','').replace('(1)','')
        
        file_path = os.path.join(train_dataset_path, filename)
        if os.path.isfile(file_path):
            # Read image
            image = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
            # Get text from image
            text = pytesseract.image_to_string(image, lang='eng').replace('\n', ' ').replace('  ',' ')
            train_corpus.loc[train_corpus['id'] == id, "text"] = text
# Out:
# Corrupt JPEG data: bad Huffman code

# %%
train_corpus.head()
# Out:
#              id                           company         date  \
# 0  X51006913007                  AEON CO. (M) BHD   27/05/2018
# 1  X51005705722    ASO ELECTRICAL TRADING SDN BHD   27/09/2017
# 2  X51005763940       ELITETRAX MARKETING SDN BHD     11.02.18
# 3  X51008099071  LEONG HENG SHELL SERVICE STATION     20/06/18
# 4  X51005757349                  GOLDEN KEY MAKER  24-MAR-2018
#
#                                              address   total  \
# 0  3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMA...   99.90
# 1  NO 31G, JALAN SEPADU C 25/C, SECTION 25, TAMAN...  248.05
# 2  LOT 1F-01&02,1ST FLR,PARADIGM MALL, NO. 1 JALA...   60.00
# 3  LOT 26151 BANDAR SG LONG, 11 1/4 MILES CHERAS,...   50.00
# 4  NO 5, JALAN KENARI 2, BANDAR PUCHONG JAYA, 471...   21.00
#
#                                                 text
# 0  AOS. 0 AEON CO. (M) BHD (126926-H) SRD FLR, AE...
# 1  ASO ELECTRICAL TRADING SDN BHD 1000131-K NO 31...
# 2    a ‘Harvey Norman   Harvey Norman M'sia Parad...
# 3    LEONG HENG SHELL SERVICE STATION Company No ...
# 4  21803053 =: ‘ GOLDEN KEY MAKER (000760274-K) N...

# %%
train_corpus.to_csv('../data/train/train_dataset.csv', index=False)

# %% [markdown]
# ## Read test (submit) data

# %%
# Unzip input dataset
# !unzip '../data/input/SROIE_test_images_task_3.zip' -d '../data/input/SROIE_test_images_task_3'

# %%
test_dataset_path = '../data/input/SROIE_test_images_task_3'

test_corpus = pd.DataFrame()

id_list = []
text_list = []

for filename in os.listdir(test_dataset_path):
    id = filename.replace('.jpg','').replace('(1)','')
    
    file_path = os.path.join(test_dataset_path, filename)
    if os.path.isfile(file_path):
        # Read image
        image = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
        # Get text from image
        text = pytesseract.image_to_string(image, lang='eng')
        # Preprocess
        text = text.replace('\n', ' ').replace('  ',' ')
        # Store informations
        id_list.append(id)
        text_list.append(text)

test_corpus['id'] = id_list
test_corpus['text'] = text_list

# %%
test_corpus.head()
# Out:
#              id                                               text
# 0  X51007846290  NOEONF UNIHAKKA INTERNATIONAL SDN BHD 07 Jun 2...
# 1  X51005447859    PASARAYA BORONG PINTAR SDN BHD BR No.: (1245...
# 2  X51005746203  / SUPER SEVEN CASH & th. SDN BHD wale 590 150-...
# 3  X51006329183  ’ tore : \o SEMBOYAN TEGAS SDN BHD we” No.5 & ...
# 4  X51005442388  A03 (26 CONTENTO (JNO761170-4) 15, JALAN PERHA...

# %%
test_corpus.to_csv('../data/test/test_dataset.csv', index=False)

# %% [markdown]
# ## Preprocessing

# %%
# Define path to file
path = '../data/train/train_dataset.csv'

# Read file 
train_corpus = pd.read_csv(path, encoding='utf8', sep=',')

# %%
train_corpus.head()
# Out:
#              id                           company         date  \
# 0  X51006913007                  AEON CO. (M) BHD   27/05/2018
# 1  X51005705722    ASO ELECTRICAL TRADING SDN BHD   27/09/2017
# 2  X51005763940       ELITETRAX MARKETING SDN BHD     11.02.18
# 3  X51008099071  LEONG HENG SHELL SERVICE STATION     20/06/18
# 4  X51005757349                  GOLDEN KEY MAKER  24-MAR-2018
#
#                                              address   total  \
# 0  3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMA...   99.90
# 1  NO 31G, JALAN SEPADU C 25/C, SECTION 25, TAMAN...  248.05
# 2  LOT 1F-01&02,1ST FLR,PARADIGM MALL, NO. 1 JALA...   60.00
# 3  LOT 26151 BANDAR SG LONG, 11 1/4 MILES CHERAS,...   50.00
# 4  NO 5, JALAN KENARI 2, BANDAR PUCHONG JAYA, 471...   21.00
#
#                                                 text
# 0  AOS. 0 AEON CO. (M) BHD (126926-H) SRD FLR, AE...
# 1  ASO ELECTRICAL TRADING SDN BHD 1000131-K NO 31...
# 2    a ‘Harvey Norman   Harvey Norman M'sia Parad...
# 3    LEONG HENG SHELL SERVICE STATION Company No ...
# 4  21803053 =: ‘ GOLDEN KEY MAKER (000760274-K) N...

# %%
# Define path to file
path = '../data/test/test_dataset.csv'

# Read file 
test_corpus = pd.read_csv(path, encoding='utf8', sep=',')

# %%
test_corpus.head()
# Out:
#              id                                               text
# 0  X51007846290  NOEONF UNIHAKKA INTERNATIONAL SDN BHD 07 Jun 2...
# 1  X51005447859    PASARAYA BORONG PINTAR SDN BHD BR No.: (1245...
# 2  X51005746203  / SUPER SEVEN CASH & th. SDN BHD wale 590 150-...
# 3  X51006329183  ’ tore : \o SEMBOYAN TEGAS SDN BHD we” No.5 & ...
# 4  X51005442388  A03 (26 CONTENTO (JNO761170-4) 15, JALAN PERHA...

# %% [markdown]
# Transform None type into string

# %%
train_corpus.fillna("",inplace=True)
test_corpus.fillna("",inplace=True)

# %% [markdown]
# Transform text column to string upper case

# %%
train_corpus['text'] = train_corpus['text'].astype(str).str.upper()
test_corpus['text'] = test_corpus['text'].astype(str).str.upper()

# %%
test_corpus['text'].head()
# Out:
# 0    NOEONF UNIHAKKA INTERNATIONAL SDN BHD 07 JUN 2...
# 1      PASARAYA BORONG PINTAR SDN BHD BR NO.: (1245...
# 2    / SUPER SEVEN CASH & TH. SDN BHD WALE 590 150-...
# 3    ’ TORE : \O SEMBOYAN TEGAS SDN BHD WE” NO.5 & ...
# 4    A03 (26 CONTENTO (JNO761170-4) 15, JALAN PERHA...
# Name: text, dtype: object

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# Convert data into a matrix of TF-IDF features

# %%
texts = pd.concat([train_corpus['text'], test_corpus['text']])

print(train_corpus['text'].shape[0])
print(test_corpus['text'].shape[0])
print(texts.shape[0])
# Out:
# 876
# 347
# 1223

# %%
vectorizer = TfidfVectorizer(sublinear_tf=True, stop_words='english', max_df=0.95, min_df=4)
tfidf = vectorizer.fit_transform(texts)

tfidf_train = tfidf[:train_corpus['text'].shape[0]]
tfidf_test = tfidf[train_corpus['text'].shape[0]:]

print(tfidf_train.shape)
print(tfidf_test.shape)
# Out:
# (876, 2617)
# (347, 2617)

# %%
x_train = tfidf_train
x_test = tfidf_test

y_company_train = train_corpus['company']
y_date_train = train_corpus['date']
y_address_train = train_corpus['address']
y_total_train = train_corpus['total']

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Functions

# %%
def classificate(classifier, x_train, y_train, x_test):
    # Create a classifier using train data
    classifier.fit(x_train, y_train)

    # Predict labels using test data
    y_pred = classifier.predict(x_test)

    return y_pred

# %% [markdown]
# ### Company

# %%
mlp_clf = MLPClassifier(hidden_layer_sizes=(100,), alpha=0.001, random_state=0)

# Create classifier
y_company_pred = classificate(mlp_clf, x_train, y_company_train, x_test)
# Out:
# /home/mayara/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
test_corpus['company'] = y_company_pred

# %%
y_company_pred
# Out:
# array(['UNIHAKKA INTERNATIONAL SDN BHD', 'PASARAYA BORONG PINTAR SDN BHD',
#        'SUPER SEVEN CASH & CARRY SDN BHD', 'GOLDEN KEY MAKER',
#        'MR. D.I.Y. (M) SDN BHD',
#        'AIK HUAT HARDWARE ENTERPRISE (SETIA ALAM) SDN BHD',
#        'YONG CEN ENTERPRISE', "KING'S CONFECTIONERY S/B",
#        'SANYU STATIONERY SHOP',
#        'AIK HUAT HARDWARE ENTERPRISE (SETIA ALAM) SDN BHD',
#        'SUPER SEVEN CASH & CARRY SDN BHD', 'SYARIKAT PERNIAGAAN GIN KEE',
#        'YHM AEON TEBRAU CITY', 'GARDENIA BAKERIES (KL) SDN BHD',
#        'ABC HO TRADING', 'C W KHOO HARDWARE SDN BHD',
#        'MR. D.I.Y. (M) SDN BHD', 'AEON CO. (M) BHD',
#        'GH DISTRIBUTOR & MARKETING SDN BHD',
#        'BECON STATIONER BECON ENTERPRISE SDN BHD',
#        'UNIHAKKA INTERNATIONAL SDN BHD',
#        'TRIPLE SIX POINT ENTERPRISE 666',
#        'GARDENIA BAKERIES (KL) SDN BHD', 'KEDAI PAPAN YEW CHUAN',
#        'OLIVE9 PHARMACY SDN BHD', '99 SPEED MART S/B',
#        'ASO ELECTRICAL TRADING SDN BHD', 'AEON CO. (M) BHD',
#        'MR. D.I.Y. (M) SDN BHD', 'TEO HENG STATIONERY & BOOKS',
#        'KEDAI PAPAN YEW CHUAN', 'GARDENIA BAKERIES (KL) SDN BHD',
#        'AIK HUAT HARDWARE ENTERPRISE (SETIA ALAM) SDN BHD',
#        'GOLDEN KEY MAKER', 'AEON CO. (M) BHD', 'PRINT EXPERT SDN BHD',
#        'YONG CEN ENTERPRISE', 'ELITETRAX MARKETING SDN BHD',
#        'RESTORAN WAN SHENG', 'GERBANG ALAF RESTAURANTS SDN BHD',
#        'TEO HENG STATIONERY & BOOKS', 'TEO HENG STATIONERY & BOOKS',
#        'AIK HUAT HARDWARE ENTERPRISE (SETIA ALAM) SDN BHD',
#        'GARDENIA BAKERIES (KL) SDN BHD', 'SEGI CASH & CARRY SDN.BHD',
#        'BEMED (SP) SDN. BHD.', 'SANYU STATIONERY SHOP',
#        'MR. D.I.Y. (M) SDN BHD', 'MR. D.I.Y. (M) SDN BHD',
#        'TEO HENG STATIONERY & BOOKS', 'PREMIO STATIONERY SDN BHD',
#        'MR. D.I.Y. (M) SDN BHD', 'SWC ENTERPRISE SDN BHD',
#        '99 SPEED MART S/B', 'GARDENIA BAKERIES (KL) SDN BHD',
#        'GARDENIA BAKERIES (KL) SDN BHD', 'UNIHAKKA INTERNATIONAL SDN BHD',
#        'MR. D.I.Y. (M) SDN BHD', 'HON HWA HARDWARE TRADING',
#        'ADVANCO COMPANY', 'MR. D.I.Y. (M) SDN BHD', '99 SPEED MART S/B',
#        'MR. D.I.Y. (M) SDN BHD', 'RESTORAN WAN SHENG',
#        'SANYU STATIONERY SHOP', 'SANYU STATIONERY SHOP',
#        'MR. D.I.Y. (M) SDN BHD', 'SYARIKAT PERNIAGAAN GIN KEE',
#        '99 SPEED MART S/B', 'SYARIKAT PERNIAGAAN GIN KEE',
#        'S.H.H. MOTOR (SUNGAI RENGIT) SDN. BHD.', 'SANYU STATIONERY SHOP',
#        'UNIHAKKA INTERNATIONAL SDN BHD', 'RESTORAN WAN SHENG',
#        'MR. D.I.Y. (M) SDN BHD', 'AEON CO. (M) BHD',
#        'B & BEST RESTAURANT', 'MR. D.I.Y. (M) SDN BHD',
#        'DIMILIKI OLEH T PLUS F&B SDN. BHD.',
#        'UNIHAKKA INTERNATIONAL SDN BHD',
#        'AIK HUAT HARDWARE ENTERPRISE (SETIA ALAM) SDN BHD',
#        'THE COFFEE BEAN & TEA LEAF (M) SDN. BHD.', 'YONG CEN ENTERPRISE',
#        'PASARAYA BORONG PINTAR SDN BHD', 'MOONLIGHT CAKE HOUSE SDN BHD',
#        'UNIHAKKA INTERNATIONAL SDN BHD', 'UNIHAKKA INTERNATIONAL SDN BHD',
#        'RESTORAN WAN SHENG', 'SYL ROASTED DELIGHTS SDN. BHD.',
#        'MR. D.I.Y. (M) SDN BHD', 'POPULAR BOOK CO. (M) SDN BHD',
#        'MR. D.I.Y. (M) SDN BHD', 'MOONLIGHT CAKE HOUSE SDN BHD',
#        'MR. D.I.Y. (M) SDN BHD', '99 SPEED MART S/B',
#        'FILL IN ENTERPRISE', 'UNIHAKKA INTERNATIONAL SDN BHD',
#        'WESTERN EASTERN ST TIONERY SDN. BHD', 'RESTORAN WAN SHENG',
#        'KEDAI PAPAN YEW CHUAN', 'MEI LET RESTAURANT',
#        'SINNATHAMBY HOLDINGS SDN. BHD.', 'BOON SENG PAPER SDN BHD',
#        'MR. D.I.Y. (M) SDN BHD', 'SANYU STATIONERY SHOP',
#        'SYARIKAT PERNIAGAAN GIN KEE',
#        'WESTERN EASTERN ST TIONERY SDN. BHD',
#        'GARDENIA BAKERIES (KL) SDN BHD', 'PINGHWAI TRADING SDN BHD',
#        'PASARAYA BORONG PINTAR SDN BHD', 'RESTORAN WAN SHENG',
#        'UNIHAKKA INTERNATIONAL SDN BHD', 'TSH POWER HARDWARE TRADING',
#        'GUARDIAN HEALTH AND BEAUTY SDN BHD',
#        'LIM SENG THO HARDWARE TRADING', 'GARDENIA BAKERIES (KL) SDN BHD',
#        'SANYU STATIONERY SHOP', 'SANYU STATIONERY SHOP',
#        'SANYU STATIONERY SHOP', 'LIAN HING STATIONERY SDN BHD',
#        'YAM FRESH', 'MR. D.I.Y. (M) SDN BHD',
#        'PASARAYA BORONG PINTAR SDN BHD', 'RESTORAN WAN SHENG',
#        'GARDENIA BAKERIES (KL) SDN BHD',
#        'WESTERN EASTERN ST TIONERY SDN. BHD',
#        'SYARIKAT PERNIAGAAN GIN KEE', 'UNIHAKKA INTERNATIONAL SDN BHD',
#        'PASAR MINI JIN SENG', 'MR. D.I.Y. (M) SDN BHD',
#        'DE MAXIMUM THAI EXPRESS SDN BHD',
#        'GERBANG ALAF RESTAURANTS SDN BHD',
#        'AIK HUAT HARDWARE ENTERPRISE (SETIA ALAM) SDN BHD',
#        'GARDENIA BAKERIES (KL) SDN BHD', 'POPULAR BOOK CO. (M) SDN BHD',
#        'AEON CO. (M) BHD', 'SANYU STATIONERY SHOP', '99 SPEED MART S/B',
#        'GARDENIA BAKERIES (KL) SDN BHD', '99 SPEED MART S/B',
#        'BEYOND BROTHERS HARDWARE', 'GARDENIA BAKERIES (KL) SDN BHD',
#        'MR. D.I.Y. (M) SDN BHD', 'URBAN IDEA SDN BHD',
#        'UNIHAKKA INTERNATIONAL SDN BHD', 'SYARIKAT PERNIAGAAN GIN KEE',
#        'MEI LET RESTAURANT',
#        'AIK HUAT HARDWARE ENTERPRISE (SETIA ALAM) SDN BHD',
#        'SYARIKAT PERNIAGAAN GIN KEE', 'RESTORAN WAN SHENG',
#        'RESTORAN WAN SHENG', 'SYL ROASTED DELIGHTS SDN. BHD.',
#        'MR. D.I.Y. (M) SDN BHD', 'YONG CEN ENTERPRISE',
#        'SANYU STATIONERY SHOP', 'BHPETROL PERMAS JAYA 2',
#        'SANYU STATIONERY SHOP', 'ARTRANGE STATIONERS & PRINT SDN BHD',
#        'TANJONGMAS BOOKCENTRE (PJ) SDN BHD', 'AEON CO. (M) BHD',
#        'PAPPARICH BMC', 'UNIHAKKA INTERNATIONAL SDN BHD',
#        '10 GRAM GOURMET SBN BHD', 'GARDENIA BAKERIES (KL) SDN BHD',
#        'SANYU STATIONERY SHOP', 'LIM SENG THO HARDWARE TRADING',
#        'AMANO MALAYSIA SDN BHD', 'LEONG HENG SHELL SERVICE STATION',
#        'S&Y STATIONERY', 'GARDENIA BAKERIES (KL) SDN BHD',
#        'GARDENIA BAKERIES (KL) SDN BHD',
#        'DIMILIKI OLEH T PLUS F&B SDN. BHD.', '99 SPEED MART S/B',
#        'SUPER SEVEN CASH & CARRY SDN BHD', 'KEDAI PAPAN YEW CHUAN',
#        'AEON CO. (M) BHD', 'GARDENIA BAKERIES (KL) SDN BHD',
#        'SYARIKAT PERNIAGAAN GIN KEE', 'SYARIKAT PERNIAGAAN GIN KEE',
#        'BHPETROL PERMAS JAYA 2', 'RESTAURANT JIAWEI JIAWEI HOUSE',
#        'SYARIKAT PERNIAGAAN GIN KEE', 'SANYU STATIONERY SHOP',
#        'UNIHAKKA INTERNATIONAL SDN BHD', 'MOONLIGHT CAKE HOUSE SDN BHD',
#        'MR. D.I.Y. (KUCHAI) SDN BHD', 'SANYU STATIONERY SHOP',
#        'SANYU STATIONERY SHOP', 'MR. D.I.Y. (M) SDN BHD',
#        'MR. D.I.Y. (M) SDN BHD', '99 SPEED MART S/B',
#        'GARDENIA BAKERIES (KL) SDN BHD', 'MR. D.I.Y. (M) SDN BHD',
#        'SANYU STATIONERY SHOP', 'RESTORAN WAN SHENG',
#        'UNIHAKKA INTERNATIONAL SDN BHD', 'UNIHAKKA INTERNATIONAL SDN BHD',
#        '99 SPEED MART S/B', 'MR. D.I.Y. (M) SDN BHD',
#        'UNIHAKKA INTERNATIONAL SDN BHD', 'MR. D.I.Y. (M) SDN BHD',
#        'AEON CO. (M) BHD', 'KEDAI PAPAN YEW CHUAN',
#        'GERBANG ALAF RESTAURANTS SDN BHD', 'MR. D.I.Y. (M) SDN BHD',
#        'GERBANG ALAF RESTAURANTS SDN BHD', 'MR. D.I.Y. (M) SDN BHD',
#        'GUARDIAN HEALTH AND BEAUTY SDN BHD',
#        'BENS INDEPENDENT GROCER SDN. BHD',
#        'LEONG HENG SHELL SERVICE STATION',
#        'SYL ROASTED DELIGHTS SDN. BHD.', '99 SPEED MART S/B',
#        'SANYU STATIONERY SHOP',
#        'AIK HUAT HARDWARE ENTERPRISE (SETIA ALAM) SDN BHD',
#        'MR. D.I.Y. (M) SDN BHD', 'GARDENIA BAKERIES (KL) SDN BHD',
#        'SYARIKAT PERNIAGAAN GIN KEE', 'SANYU STATIONERY SHOP',
#        "KING'S CONFECTIONERY S/B", 'UNIHAKKA INTERNATIONAL SDN BHD',
#        'SYARIKAT PERNIAGAAN GIN KEE', 'POPULAR BOOK CO. (M) SDN BHD',
#        'GARDENIA BAKERIES (KL) SDN BHD', '99 SPEED MART S/B',
#        'PRINT EXPERT SDN BHD', 'GARDENIA BAKERIES (KL) SDN BHD',
#        'GARDENIA BAKERIES (KL) SDN BHD', 'MR. D.I.Y. (M) SDN BHD',
#        'RESTORAN WAN SHENG', 'MR. D.I.Y. (M) SDN BHD', 'ADVANCO COMPANY',
#        'VIVOPAC MARKETING SDN BHD', 'GARDENIA BAKERIES (KL) SDN BHD',
#        'UNIHAKKA INTERNATIONAL SDN BHD', 'GARDENIA BAKERIES (KL) SDN BHD',
#        'SYARIKAT PERNIAGAAN GIN KEE', 'MR. D.I.Y. (M) SDN BHD',
#        'KEDAI PAPAN YEW CHUAN', 'MR. D.I.Y. (M) SDN BHD',
#        'MR. D.I.Y. (M) SDN BHD', 'SANYU STATIONERY SHOP',
#        '99 SPEED MART S/B', 'GOLDEN ARCHES RESTAURANTS SDN BHD',
#        'SINNATHAMBY HOLDINGS SDN. BHD.', 'POPULAR BOOK CO. (M) SDN BHD',
#        'UNIHAKKA INTERNATIONAL SDN BHD', 'RESTORAN WAN SHENG',
#        "KING'S CONFECTIONERY S/B", 'UNIHAKKA INTERNATIONAL SDN BHD',
#        'MR. D.I.Y. (M) SDN BHD', 'SUBANG HEALTHCARE SDN BHD',
#        'UNIHAKKA INTERNATIONAL SDN BHD', 'AEON CO. (M) BHD',
#        'AIK HUAT HARDWARE ENTERPRISE (SETIA ALAM) SDN BHD',
#        'MR. D.I.Y. (M) SDN BHD', 'BEMED (SP) SDN BHD',
#        'MR. D.I.Y. (M) SDN BHD', 'SANYU STATIONERY SHOP',
#        'GARDENIA BAKERIES (KL) SDN BHD', 'MR. D.I.Y. (M) SDN BHD',
#        'GUARDIAN HEALTH AND BEAUTY SDN BHD',
#        'UNIHAKKA INTERNATIONAL SDN BHD', 'SYARIKAT PERNIAGAAN GIN KEE',
#        'POPULAR BOOK CO. (M) SDN BHD', 'GREEN LANE PHARMACY SDN BHD',
#        'SANYU STATIONERY SHOP', 'MR. D.I.Y. (M) SDN BHD',
#        'GARDENIA BAKERIES (KL) SDN BHD', 'MOONLIGHT CAKE HOUSE SDN BHD',
#        '99 SPEED MART S/B', 'SYARIKAT PERNIAGAAN GIN KEE',
#        'AMANO MALAYSIA SDN BHD', 'UNIHAKKA INTERNATIONAL SDN BHD',
#        'MR. D.I.Y. (M) SDN BHD', 'MR. D.I.Y. (M) SDN BHD',
#        'MR. D.I.Y. (M) SDN BHD', 'C W KHOO HARDWARE SDN BHD',
#        'MR. D.I.Y. (M) SDN BHD', 'GARDENIA BAKERIES (KL) SDN BHD',
#        'BEMED (SP) SDN. BHD.', 'MR. D.I.Y. (M) SDN BHD',
#        'LIGHTROOM GALLERY SDN BHD', 'ELITETRAX MARKETING SDN BHD',
#        'MR. D.I.Y. (M) SDN BHD', '99 SPEED MART S/B',
#        'MR. D.I.Y. (KUCHAI) SDN BHD', 'UNIHAKKA INTERNATIONAL SDN BHD',
#        '99 SPEED MART S/B', '99 SPEED MART S/B', 'RESTORAN WAN SHENG',
#        'UNIHAKKA INTERNATIONAL SDN BHD', 'GARDENIA BAKERIES (KL) SDN BHD',
#        'GARDENIA BAKERIES (KL) SDN BHD', 'AEON CO. (M) BHD',
#        'UNIHAKKA INTERNATIONAL SDN BHD', 'BEMED (SP) SDN. BHD.',
#        'AIK HUAT HARDWARE ENTERPRISE (SETIA ALAM) SDN BHD',
#        'UNIHAKKA INTERNATIONAL SDN BHD', 'HON HWA HARDWARE TRADING',
#        'GARDENIA BAKERIES (KL) SDN BHD', 'POPULAR BOOK CO. (M) SDN BHD',
#        'AEON CO. (M) BHD', 'UNIHAKKA INTERNATIONAL SDN BHD',
#        'GARDENIA BAKERIES (KL) SDN BHD', 'HON HWA HARDWARE TRADING',
#        'SUPER SEVEN CASH & CARRY SDN BHD', 'MR. D.I.Y. (M) SDN BHD',
#        'KEDAI PAPAN YEW CHUAN', '99 SPEED MART S/B',
#        'PERNIAGAAN ZHENG HUI', 'THE TOAST F&B SDN BHD',
#        'UNIHAKKA INTERNATIONAL SDN BHD', 'UNIHAKKA INTERNATIONAL SDN BHD',
#        'MR. D.I.Y. (M) SDN BHD', 'SYARIKAT PERNIAGAAN GIN KEE',
#        'GERBANG ALAF RESTAURANTS SDN BHD', 'YONG TAT HARDWARE TRADING',
#        'VIVOPAC MARKETING SDN BHD', 'RESTORAN WAN SHENG',
#        'AEON CO. (M) BHD', 'AEON CO. (M) BHD', 'KEDAI PAPAN YEW CHUAN',
#        'SYARIKAT PERNIAGAAN GIN KEE', 'BROADVIEW MARKETING SDN BHD',
#        'HON HWA HARDWARE TRADING', 'FAMILYMART', 'MR. D.I.Y. (M) SDN BHD',
#        'RESTORAN WAN SHENG', '99 SPEED MART S/B',
#        'GERBANG ALAF RESTAURANTS SDN BHD', '99 SPEED MART S/B',
#        'SYARIKAT PERNIAGAAN GIN KEE',
#        'GHEE HIANG GH DISTRIBUTOR & MARKETING SDN BHD',
#        'PRINT EXPERT SDN BHD', 'UNIHAKKA INTERNATIONAL SDN BHD',
#        'GARDENIA BAKERIES (KL) SDN BHD',
#        'GERBANG ALAF RESTAURANTS SDN BHD',
#        'UROKO JAPANESE CUISINE SDN BHD', 'MR. D.I.Y. (M) SDN BHD',
#        'BENS INDEPENDENT GROCER SDN. BHD', 'AEON CO. (M) BHD',
#        'ELITETRAX MARKETING SDN BHD', 'MR. D.I.Y. (M) SDN BHD',
#        'LIGHTROOM GALLERY SDN BHD', 'PASARAYA BORONG PINTAR SDN BHD',
#        'MR. D.I.Y. (M) SDN BHD', 'LIM SENG THO HARDWARE TRADING'],
#       dtype='<U49')

# %% [markdown]
# ### Date

# %%
svm_clf = SVC(kernel='poly', C=1000, random_state=0)

# Create classifier
y_date_pred = classificate(svm_clf, x_train, y_date_train, x_test)

# %%
test_corpus['date'] = y_date_pred

# %%
y_date_pred
# Out:
# array(['20 JUN 2018', '20180304', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '16 MAY 2018', '24-03-18', '24-03-18', '24-03-18', '31/03/2017',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-MAR-2018', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '09 MAY 2018', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '21-03-2018', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '20180304', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '19/03/2018', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '14-03-2018', '16 APR 2018', '24-03-18', '24-03-18', '09/02/2018',
#        '24-03-18', '24/07/2017', '24/07/2017', '24/07/2017', '27/03/2018',
#        '2016-07-31', '24-03-18', '20180304', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '19-03-2018',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '17/03/2017', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '03/02/2018', '30/04/2017', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '10 APR 2018', '24-03-18', '24-03-18', '16 JUN 2018',
#        '24-03-18', '24-03-18', '28/02/2018', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24/07/2017', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24/07/2017', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '16-03-2018', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '10 APR 2018', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '14 MAY 2018', '24-03-18', '24-03-18', '02 APR 2018', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '02/JAN/2017', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '08/07/2017', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '15 MAY 2018', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '07-02-17', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '09 MAY 2018', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '19 APR 2018', '24-03-18', '21/09/2017',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '18 APR 2018', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '11/05/2018', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '24-03-18',
#        '24-03-18', '24-03-18', '24-03-18', '24-03-18', '20180304',
#        '24-03-18', '24-03-18'], dtype=object)

# %% [markdown]
# ### Address

# %%
mlp_clf = MLPClassifier(hidden_layer_sizes=(300,), alpha=0.001, random_state=0)

# Create classifier
y_address_pred = classificate(mlp_clf, x_train, y_address_train, x_test)
# Out:
# /home/mayara/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
test_corpus['address'] = y_address_pred

# %%
y_address_pred
# Out:
# array(['12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU, JOHOR',
#        'NO 19-G& 19-1& 19-2 JALAN TASIK UTAMA 4, MEDAN NIAGA TASIK DAMAI',
#        'NO. 1 JALAN EURO 1 OFF JALAN BATU TIGA SUNGAI BULOH SEKSYEN U3 SHAH ALAM, 40150',
#        'NO. 53, JALAN BESAR, 45600 BATANG BERJUNTAI SELANGOR DARUL EHSAN',
#        'NO. 17-G, JALAN SETIA INDAH (X) U13/X, SETIA ALAM, SEKSYEN U13, 40170 SHAH ALAM,',
#        'UNIT L1-044B, VIVACITY MEGAMALL, JALAN WAN ALWI, 93350 KUCHING, SARAWAK.',
#        '9, JALAN SUBANG JASA 3, 40150 SHAN ALAM, SELANGOR.',
#        'LOT NO. G23, GIANT KELANA JAYA LOT PT244, JLN PERBANDARAN SS6/4 PUSAT BANDAR KELANA JAYA, PETALING',
#        'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#        'NO. 17-G, JALAN SETIA INDAH (X) U13/X, SETIA ALAM, SEKSYEN U13, 40170 SHAH ALAM,',
#        'NO. 1 JALAN EURO 1 OFF JALAN BATU TIGA SUNGAI BULOH SEKSYEN U3 SHAH ALAM, 40150',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'S117, SECOND FLOOR, AEON TEBRAU CITY, 1, JALAN DESA TEBRAU, TAMAN DESA TEBRAU, 81100 JOHOR BAHRU, JOHOR.',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'NO.2&4, JALAN HARMONI 3/2, TAMAN DESA HARMONI. 81100 JOHOR BAHRU JOHOR',
#        'NO.50,JALAN PBS 14/11, KAWASAN PERINDUSTRIAN BUKIT SERDANG,',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#        '95, BEACH ROAD, 10300 PENANG. 10400 PENANG.',
#        'NO.41G, JLN SS21/60, DAMANSARA UTAMA, 47400 PJ, SELANGOR.',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'NO 14 & 16 JALAN PERMAS 4/3 BANDAR BARU PERMAS JAY',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'LOT 276 JALAN BANTING 43800 DENGKIL, SELANGOR.',
#        '69 JALAN NOVA U5/N, SEKSYEN U5 SUBANG BE',
#        'LOT P.T. 33198, BATU 4 JALAN KAPAR, MUKIM KAPAR 42100 KLANG, SELANGOR 1605-TMN SRI BINTANG',
#        'NO 31G, JALAN SEPADU C 25/C, SECTION 25, TAMAN INDUSTRIES, AXIS 40400 SHAH ALAM, SELANGOR.',
#        '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#        'LOT 276 JALAN BANTING 43800 DENGKIL, SELANGOR',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'NO. 17-G, JALAN SETIA INDAH (X) U13/X, SETIA ALAM, SEKSYEN U13, 40170 SHAH ALAM,',
#        'NO 5, JALAN KENARI 2, BANDAR PUCHONG JAYA, 47100 PUCHONG, SELANGOR',
#        '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#        'NO 18, 20, 22, JALAN BUNGA TANJONG 2/16, 40000 SHAH ALAM, SELANGOR',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'NO.128G JLN SS21/35 DAMANSARA UTAMA PETALING JAYA 47400 SELANGOR',
#        'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#        'LEVEL 6, BANGUNAN TH, DAMANSARA UPTOWN3 NO.3, JALAN SS21/39,47400 PETALING JAYA SELANGOR',
#        'NO. 53, JALAN BESAR, 45600 BATANG BERJUNTAI SELANGOR DARUL EHSAN',
#        'NO. 53, JALAN BESAR, 45600 BATANG BERJUNTAI SELANGOR DARUL EHSAN',
#        'NO. 17-G, JALAN SETIA INDAH (X) U13/X, SETIA ALAM, SEKSYEN U13, 40170 SHAH ALAM,',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'PT17920, SEKSYEN U9, 40150 SHAH ALAM, SELANGOR DARUL EHSAN.',
#        'NO.49, JALAN DINAR G U3/G, SUBANG PERDANA, 40150 SHAH ALAM, SELANGOR D.E.',
#        'NO.128G JLN SS21/35 DAMANSARA UTAMA PETALING JAYA 47400 SELANGOR',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO. 53, JALAN BESAR, 45600 BATANG BERJUNTAI SELANGOR DARUL EHSAN',
#        'F-G-01 JALAN SS 6/5B DATARAN GLOMAC. KELANA JAYA 47301 PETALING JAYA. SELANGOR',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        '5-7, JALAN MAHAGONI 7/1 SEKSYEN 4, BANDAR UTAMA, 44300 BATANG KALI, SELANGOR',
#        'LOT P.T. 33198, BATU 4 JALAN KAPAR, MUKIM KAPAR 42100 KLANG, SELANGOR 1558-TMN PUSAT KEPONG',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO 37, JALAN MANIS 7, TAMAN SEGAR, 56100 CHERAS, KUALA LUMPUR.',
#        'NO 1&3, JALAN WANGSA DELIMA 12, WANGSA LINK, WANGSA MAJU, 53300 KUALA LUMPUR',
#        'PT17920, SEKSYEN U9, 40150 SHAH ALAM, SELANGOR DARUL EHSAN.',
#        'LOT P. T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR 1181-TMN SRI SINAR',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#        'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#        'A-16-1, TOWER A, NORTHPOINT OFFICE, MID VALLEY CITY, NO1, MEDAN SYED PUTRA UTARA KUALA LUMPUR MALAYSIA',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'LOT P.T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR 1249-TMN PANDAN CAHAYA',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'NO.2&4, JALAN HARMONI 3/2, TAMAN DESA HARMONI. 81100 JOHOR BAHRU JOHOR',
#        'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO.12,JALAN SS4C/5,PETALING JAYA SELANGOR DARUL EHSAN',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'NO. 17-G, JALAN SETIA INDAH (X) U13/X, SETIA ALAM, SEKSYEN U13, 40170 SHAH ALAM,',
#        'F.K06, FIRST FLOOR, THE GARDENS MALL, MID VALLEY CITY, LINGKARAN SYED PUTRA, 59200 KUALA LUMPUR.',
#        '9, JALAN SUBANG JASA 3, 40150 SHAN ALAM, SELANGOR.',
#        'NO 19-G& 19-1& 19-2 JALAN TASIK UTAMA 4, MEDAN NIAGA TASIK DAMAI',
#        'NO.1, JALAN PERMAS 10/5, BANDAR BARU PERMAS JAYA 81750 JOHOR BAHRU, JOHOR.',
#        'NO.3 & 5, JALAN PERMAS 11, BANDAR BARU PERMAS JAYA, 81750 MASAI, JOHOR',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#        'S117, SECOND FLOOR, AEON TEBRAU CITY, 1, JALAN DESA TEBRAU, TAMAN DESA TEBRAU, 81100 JOHOR BAHRU, JOHOR.',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'NO 8, JALAN 7/118B, DESA TUN RAZAK 56000 KUALA LUMPUR, MALAYSIA',
#        'NO. 17-G, JALAN SETIA INDAH (X) U13/X, SETIA ALAM, SEKSYEN U13, 40170 SHAH ALAM,',
#        'NO.1, JALAN PERMAS 10/5, BANDAR BARU PERMAS JAYA 81750 JOHOR BAHRU, JOHOR.',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'LOT P.T. 33198, BATU 4 JALAN KAPAR, MUKIM KAPAR 42100 KLANG, SELANGOR 1558-TMN PUSAT KEPONG',
#        'LOT 2407, JALAN DUA 52100 KEPONG BARU, KL',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        '42-46, JLN SULTAN AZLAN SHAH 51200 KUALA LUMPUR',
#        'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#        'LOT 276 JALAN BANTING 43800 DENGKIL, SELANGOR',
#        'NO 2, JALAN BULAN BM U5/BM, SEKSYEN U5, 40150 SHAH ALAM, SELANGOR',
#        '22, JALAN PERINDUSTRIAN HIJAU 5, TAMAN PERINDUSTRIAN HIJAU,',
#        '12, JALAN BUNGA TANJUNG,2/16 SEKSYEN 2,40000 SHAH ALAM, SELANGOR',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        '42-46, JLN SULTAN AZLAN SHAH 51200 KUALA LUMPUR',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'NO.2, JALAN METRO PERDANA TIMUR 11, KEPONG ENTERPRENUERS PARK, OFF JALAN KEPONG, 52100 KUALA LUMPUR.',
#        'NO 19-G& 19-1& 19-2 JALAN TASIK UTAMA 4, MEDAN NIAGA TASIK DAMAI',
#        'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        '13-1, JALAN PJU 5/10, DATARAN SUNWAY, KOTA DAMANSARA, 47810, PETALING JAYA, SELANGOR',
#        'LOT B-005-006, BASEMENT LEVEL 1 THE STARLING MALL JALAN SS21/60, DAMANSARA UTAMA.',
#        'NO 7, SIMPANG OFF BATU VILLAGE, JALAN IPOH BATU 5, 51200 KUALA LUMPUR MALAYSIA',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#        'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#        'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#        'NO.32 & 33, JALAN SR 1/9, SEKSYEN 9, TAMAN SERDANG RAYA, 43300 SERI KEMBANGAN, SELANGOR DARUL EHSAN',
#        'NO.145G, JALAN RIMBUNAN RAYA 1, LAMAN RIMBUNAN KEPONG, 52100 KUALA LUMPUR',
#        'NO. 47, JALAN MERANTI 1A, BANDAR BARU UTAMA, 44300 BATANG KALI, SELANGOR.',
#        'NO 19-G& 19-1& 19-2 JALAN TASIK UTAMA 4, MEDAN NIAGA TASIK DAMAI',
#        'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        '42-46, JLN SULTAN AZLAN SHAH 51200 KUALA LUMPUR',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        '379, JALAN PERMAS SATU, BANDAR BARU PERMAS JAYA 81750 PLENTONG, JOHOR.',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'LOT 2110&2111 JALAN PERMAS UTARA BANDAR BARU PERMAS 81750 JOHOR BAHRU JOHOR',
#        'LEVEL 6, BANGUNAN TH, DAMANSARA UPTOWN3 NO.3, JALAN SS21/39, 47400 PETALING JAYA SELANGOR',
#        'NO. 17-G, JALAN SETIA INDAH (X) U13/X, SETIA ALAM, SEKSYEN U13, 40170 SHAH ALAM,',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'NO 8, JALAN 7/118B, DESA TUN RAZAK 56000 KUALA LUMPUR, MALAYSIA',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#        'LOT P.T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR 1214-JINJANG UTARA',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'LOT P.T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR 1214-JINJANG UTARA',
#        'LOT 1-0-2, JLN 1/50, DIAMOND SQUARE, OFF JLN GOMBAK 53000 KUALA LUMPUR',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'A-G-06, DATARAN GLOMAC, JALAN SS6/5A, PUSAT BANDAR KELANA JAYA, 47301 PETALING JAYA, SELANGOR, MALAYSIA',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'NO 2, JALAN BULAN BM U5/BM, SEKSYEN U5, 40150 SHAH ALAM, SELANGOR',
#        'NO. 17-G, JALAN SETIA INDAH (X) U13/X, SETIA ALAM, SEKSYEN U13, 40170 SHAH ALAM,',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#        'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#        'NO 14 & 16 JALAN PERMAS 4/3 BANDAR BARU PERMAS JAY',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        '9, JALAN SUBANG JASA 3, 40150 SHAH ALAM, SELANGOR.',
#        'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#        'LOT PTD 101051 JALAN PERMAS 10/10 81750 MASAI, JOHOR',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'NO. 17-G, JALAN SETIA INDAH (X) U13/X, SETIA ALAM, SEKSYEN U13, 40170 SHAH ALAM,',
#        'LOT F15, GIANT BANDAR PUTERI JALAN PUTERI 1/1, BDR PUTERI 47100 PUCHONG, SELANGOR',
#        '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#        'JALAN TEMENGGUNG 23/9 BANDAR MAHKOTA CHERAS 43200 SELANGOR DARUL EHSAN, MALAYSIA',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'NO 3, JALAN TEMENGGUNG 27/9 BANDAR MAHKOTA CHERAS, 43200 SELANGOR.',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#        'NO 7, SIMPANG OFF BATU VILLAGE, JALAN IPOH BATU 5, 51200 KUALA LUMPUR MALAYSIA',
#        '12 JALAN PENGACARA U1/48 TEMASYA INDUSTRIAL PARK 40150 SHAH ALAM SELANGOR',
#        'LOT 26151 BANDAR SG LONG, 11 1/4 MILES CHERAS, 43000 KAJANG, SELANGOR',
#        'NO. 36G JALAN BULAN BM U5/BM, BANDAR PINGGIRAN SUBANG, SEKSYEN U5, 40150 SHAH ALAM, SELANGOR.',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        '54,JALAN SS23/11 TAMAN SEA,47400 PETALING JAYA,SELANGOR',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO. 1 JALAN EURO 1 OFF JALAN BATU TIGA SUNGAI BULOH SEKSYEN U3 SHAH ALAM, 40150',
#        'LOT 276 JALAN BANTING 43800 DENGKIL, SELANGOR.',
#        'NO.1, JALAN PERMAS 10/5, BANDAR BARU PERMAS JAYA 81750 JOHOR BAHRU, JOHOR.',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'LOT PTD 101051 JALAN PERMAS 10/10 81750 MASAI, JOHOR',
#        '13, JLN TASIK UTAMA 8 MEDAN NIAGA DAMAI SG BESI 57000 KL',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'NO.1, JALAN PERMAS 10/5, BANDAR BARU PERMAS JAYA 81750 JOHOR BAHRU, JOHOR.',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#        'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#        '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        '379, JALAN PERMAS SATU, BANDAR BARU PERMAS JAYA 81750 PLENTONG, JOHOR.',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'LOT S319, 2ND FLOOR, 1 UTAMA SHOPPING CENTRE, NO1, LEBUH BANDAR UTAMA,47800 P.JAYA',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'LOT P.T. 33198, BATU 4 JALAN KAPAR, MUKIM KAPAR 42100 KLANG, SELANGOR 1181-TMN SRI SINAR',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU, JOHOR',
#        'PT17920, SEKSYEN U9, 40150 SHAH ALAM, SELANGOR DARUL EHSAN.',
#        '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#        'LOT 276 JALAN BANTING 43800 DENGKIL, SELANGOR',
#        'LEVEL 6, BANGUNAN TH, DAMANSARA UPTOWN3 NO.3, JALAN SS21/39,47400 PETALING JAYA SELANGOR',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'LEVEL 6, BANGUNAN TH, DAMANSARA UPTOWN3 NO.3, JALAN SS21/39, 47400 PETALING JAYA SELANGOR',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'LOT B-005-006, BASEMENT LEVEL 1 THE STARLING MALL JALAN SS21/60, DAMANSARA UTAMA.',
#        'LOT 6, JALAN BATAI, PLAZA BATAI, DAMANSARA HEIGHTS 50490, KUALA LUMPUR',
#        'LOT PT 1138 ,PT 33122, BANDAR MAHKOTA CHERAS 43200 CHERAS, SELANGOR',
#        'LOT S319, 2ND FLOOR, 1 UTAMA SHOPPING CENTRE, NO1, LEBUH BANDAR UTAMA,47800 P.JAYA',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#        'NO. 17-G, JALAN SETIA INDAH (X) U13/X, SETIA ALAM, SEKSYEN U13, 40170 SHAH ALAM,',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#        'LOT NO. G23, GIANT KELANA JAYA LOT PT244, JLN PERBANDARAN SS6/4 PUSAT BANDAR KELANA JAYA, PETALING',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'NO 8, JALAN 7/118B, DESA TUN RAZAK 56000 KUALA LUMPUR, MALAYSIA',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'LOT P.T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR 1214-JINJANG UTARA',
#        'NO 18, 20, 22, JALAN BUNGA TANJONG 2/16, 40000 SHAH ALAM, SELANGOR',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        '14 JALAN MANIS 4 TAMAN SEGAR 56100 KL',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#        'LOT 276 JALAN BANTING 43800 DENGKIL, SELANGOR',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        '5,JALAN PERMAS 10/5, BANDAR BARU PERMAS JAYA, 81750 JOHOR BAHRU,JOHOR',
#        'LEVEL 6, BANGUNAN TH, DAMANSARA UPTOWN3 NO.3, JALAN SS21/39,47400 PETALING JAYA SELANGOR',
#        'NO.89&91, JALAN UTAMA, TAMAN MUTIA RINI, 81300 SKUDAI, JOHOR.',
#        'NO 8, JALAN 7/118B, DESA TUN RAZAK 56000 KUALA LUMPUR, MALAYSIA',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#        'LOT NO. G23, GIANT KELANA JAYA LOT PT244, JLN PERBANDARAN SS6/4 PUSAT BANDAR KELANA JAYA, PETALING',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'B-8, JALAN SS15/4D, 47500 SUBANG JAYA, SELANGOR',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#        'NO. 17-G, JALAN SETIA INDAH (X) U13/X, SETIA ALAM, SEKSYEN U13, 40170 SHAH ALAM,',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO.49, JALAN DINAR G U3/G, SUBANG PERDANA, 40150 SHAH ALAM, SELANGOR D.E.',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'LOT B-005-006, BASEMENT LEVEL 1 THE STARLING MALL JALAN SS21/60, DAMANSARA UTAMA.',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'NO 8, JALAN 7/118B, DESA TUN RAZAK 56000 KUALA LUMPUR, MALAYSIA',
#        '33 JLN BANGAU 1,KEPONG BARU, 52100 KEPONG,KL',
#        'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'NO.1, JALAN PERMAS 10/5, BANDAR BARU PERMAS JAYA 81750 JOHOR BAHRU, JOHOR.',
#        'S117, SECOND FLOOR, AEON TEBRAU CITY, 1, JALAN DESA TEBRAU, TAMAN DESA TEBRAU, 81100 JOHOR BAHRU, JOHOR.',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        '12 JALAN PENGACARA U1/48 TEMASYA INDUSTRIAL PARK 40150 SHAH ALAM SELANGOR',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO.50,JALAN PBS 14/11, KAWASAN PERINDUSTRIAN BUKIT SERDANG,',
#        '54,JALAN SS23/11 TAMAN SEA,47400 PETALING JAYA,SELANGOR',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'NO.49, JALAN DINAR G U3/G, SUBANG PERDANA, 40150 SHAH ALAM, SELANGOR D.E.',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO: 28, JALAN ASTANA 1C, BANDAR BUKIT RAJA, 41050 KLANG SELANGOR D.E, MALAYSIA',
#        'LOT P.T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR 1214-JINJANG UTARA',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU, JOHOR',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'LOT P.T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR',
#        'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'NO.49, JALAN DINAR G U3/G, SUBANG PERDANA, 40150 SHAH ALAM, SELANGOR D.E.',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'NO 37, JALAN MANIS 7, TAMAN SEGAR, 56100 CHERAS, KUALA LUMPUR.',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'NO 8, JALAN 7/118B, DESA TUN RAZAK 56000 KUALA LUMPUR, MALAYSIA',
#        '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'NO 37, JALAN MANIS 7, TAMAN SEGAR, 56100 CHERAS, KUALA LUMPUR.',
#        'NO. 1 JALAN EURO 1 OFF JALAN BATU TIGA SUNGAI BULOH SEKSYEN U3 SHAH ALAM, 40150',
#        'NO. 47, JALAN MERANTI 1A, BANDAR BARU UTAMA, 44300 BATANG KALI, SELANGOR.',
#        'LOT 276 JALAN BANTING 43800 DENGKIL, SELANGOR.',
#        'LOT P.T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR 1214-JINJANG UTARA',
#        'NO.59 JALAN PERMAS 9/5 BANDAR BARU PERMAS JAYA 81750 JOHOR BAHRU',
#        'LOT 2110&2111 JALAN PERMAS UTARA BANDAR BARU PERMAS 81750 JOHOR BAHRU JOHOR',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'LEVEL 6, BANGUNAN TH, DAMANSARA UPTOWN3 NO.3, JALAN SS21/39, 47400 PETALING JAYA SELANGOR',
#        'NO 4,JALAN PERJIRANAN 10, TAMAN AIR BIRU, 81700 PASIR GUDANG, JOHOR.',
#        '14 JALAN MANIS 4 TAMAN SEGAR 56100 KL',
#        'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#        '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#        '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#        'LOT 276 JALAN BANTING 43800 DENGKIL, SELANGOR',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'NO. 9-G, JALAN DINAR D U3/D TAMAN SUBANG PERDANA, SEK,U3, 40150 SHAH ALAM,SELANGOR D.E.',
#        'NO 37, JALAN MANIS 7, TAMAN SEGAR, 56100 CHERAS, KUALA LUMPUR.',
#        'NO 16A, JALAN ASTAKA U8/83, BUKIT JELUTONG. 40150 SHAH ALAM, SELANGOR, D.E.',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#        'LOT P.T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR 1225-DENGKIL',
#        'LEVEL 6, BANGUNAN TH, DAMANSARA UPTOWN3 NO.3, JALAN SS21/39,47400 PETALING JAYA SELANGOR',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#        '95, BEACH ROAD, 10300 PENANG. 10400 PENANG.',
#        'NO 18, 20, 22, JALAN BUNGA TANJONG 2/16, 40000 SHAH ALAM, SELANGOR',
#        '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#        'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#        'LEVEL 6, BANGUNAN TH, DAMANSARA UPTOWN3 NO.3, JALAN SS21/39,47400 PETALING JAYA SELANGOR',
#        '22A-1, JALAN 17/54, SECTION 17, 46400 PETALING JAYA, SELANGOR.',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'LOT 6, JALAN BATAI, PLAZA BATAI, DAMANSARA HEIGHTS 50490, KUALA LUMPUR',
#        '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#        'NO: G3, BLK G, JLN PJU 1A/3, ARA DAMANSARA, 47301 PETALING JAYA, SELANGOR DARUL EHSAN.',
#        'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#        'NO: 28, JALAN ASTANA 1C, BANDAR BUKIT RAJA, 41050 KLANG SELANGOR D.E, MALAYSIA',
#        'NO 19-G& 19-1& 19-2 JALAN TASIK UTAMA 4, MEDAN NIAGA TASIK DAMAI',
#        'L4-17 (B), LEVEL 4, UP2-01, MELAWATI MALL, 355, JALAN BANDAR MELAWATI, PUSAT BANDAR MELAWATI, 53100 KUALA LUMPUR.',
#        'NO 7, SIMPANG OFF BATU VILLAGE, JALAN IPOH BATU 5, 51200 KUALA LUMPUR MALAYSIA'],
#       dtype='<U135')

# %% [markdown]
# ### Total

# %%
mlp_clf = MLPClassifier(hidden_layer_sizes=(500,), alpha=0.0001, random_state=0)

# Create classifier
y_total_pred = classificate(mlp_clf, x_train, y_total_train, x_test)
# Out:
# /home/mayara/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
test_corpus['total'] = y_total_pred

# %%
y_total_pred
# Out:
# array(['RM8.20', '3.20', 'RM367.10', '6.00', '28.00', '6.00', '63.35',
#        '7.50', '33.50', '14.90', 'RM367.10', '21.20', '13.10', '41.87',
#        '31.00', '48.00', '7.00', '5.90', '25.00', '247.55', '$8.20',
#        '7.60', '27.20', '87.45', '12.15', '177.20', '99.00', '6.00',
#        '7838.80', '11.60', '404.39', '73.55', '7.00', '21.00', '46.55',
#        '100.00', '26.10', '6.00', '7.00', '18.90', '4.90', '4.90', '6.00',
#        '14.79', '20.05', '165.00', '7.00', '5.00', '7838.80', '27.55',
#        '25.45', '7838.80', '9.00', '27.30', '68.63', '51.88', '$6.60',
#        '21.00', '10.40', '7.00', '20.05', '9.90', '7.00', '6.70', '3.90',
#        '39.90', '7838.80', '6.36', '9.90', '74.20', '31.00', '5.80',
#        '$8.20', '6.70', '7838.80', '5.00', '7.40', '2.10', '42.40',
#        'RM7.70', '6.00', '12.00', '63.35', '3.20', 'RM14.20', '13.80',
#        '5.00', '9.60', '6.00', '5.00', '21.00', '6.00', 'RM14.20',
#        'RM 3.30', '27.30', '100.00', '36.00', 'RM5.00', '4.80', '178.08',
#        '67.85', '7.00', '31.80', '7838.80', '7.00', '6.00', 'RM5.00',
#        '34.21', '616.60', '8.20', '4.80', '$8.20', '8.00', '2.56', '7.00',
#        '73.55', '3.90', '3.00', '5.80', '79.50', 'RM8.35', '9.00', '3.20',
#        '6.00', '53.14', 'RM5.00', '13.25', '$8.20', '7.00', '23.00',
#        '30.70', '8.50', '7.00', '31.05', '21.00', '6.00', '8.70', '45.35',
#        '68.41', '15.90', '63.60', '23.56', '7838.80', 'RM22.65', 'RM8.50',
#        '7.00', '67.85', '6.00', '94.87', '6.00', '9.60', '7.60',
#        '7838.80', '6.00', '8.70', '50.00', '12.00', '42.40', '62.00',
#        '5.90', '72.93', 'RM7.70', '15.00', '60.24', '5.00', '7.00',
#        'RM3.00', '50.00', '72.00', '31.32', '34.21', '53.55', '7.00',
#        'RM367.10', '162.71', '12.00', '39.78', '23.32', '94.87', '50.00',
#        '65.20', '6.00', '6.00', 'RM6.00', '15.15', '17.45', '6.00',
#        '5.00', '7.00', '7838.80', '28.50', '34.21', '31.45', '374.20',
#        '4.80', '$8.20', '$7.60', '11.40', 'RM 68.10', 'RM7.70', '5.00',
#        '5.90', '101.76', '26.60', '7838.80', '8.50', '12.30', '13.78',
#        '77.20', '100.00', '30.30', '6.00', '2.00', '9.00', '6.00',
#        '31.05', '21.20', '5.80', '7.50', '$8.20', '23.32', '9.90',
#        '62.60', '7.00', '4.25', '5.90', '24.83', '$8.70', '9.60', '5.00',
#        '42.40', '18.80', '50.60', '$7.60', '5.90', '7.00', '33.50',
#        '87.45', '5.00', '48.10', '6.00', '6.00', '28.20', '9.00', '9.90',
#        '$8.90', '4.60', '7.50', '$8.20', '14.90', '4.90', 'RM8.50',
#        '99.90', '7.00', '10.60', '165.00', '5.90', '5.80', '39.87',
#        '3.90', '13.78', '$11.20', '5.30', '9.90', '180.10', '8.70',
#        '7838.80', '27.20', 'RM15.40', '12.30', '7.00', 'RM3.00', '$8.20',
#        '5.00', '48.10', '6.00', '21.20', '7.00', '110.46', '165.00',
#        '7838.80', '73.00', '7.00', '4.00', '6.00', 'RM 22.90', 'RM7.70',
#        '6.00', '37.45', '4.80', '$8.90', '33.80', '48.04', '5.90',
#        'RM7.70', '165.00', '5.00', '$6.60', '10.40', '39.78', '30.10',
#        '476.80', '$9.90', '54.19', '10.40', 'RM367.10', '25.00', '162.71',
#        '27.30', '112.45', '28.15', '$8.20', '$7.00', '7.00', '74.20',
#        '13.10', '100.90', '18.80', '4.80', '5.90', '127.35', '68.90',
#        '12.00', '6.00', '10.40', '18.80', '7838.80', '4.80', '9.90',
#        '26.60', '6.00', '74.20', '25.00', '4.25', 'RM8.20', '14.79',
#        '8.50', '87.10', '2.10', '77.20', '5.90', '6.00', '2.10', '73.00',
#        '3.20', '7838.80', '7.00'], dtype='<U8')

# %% [markdown]
# ## Add data to .txt file

# %%
test_corpus.head()
# Out:
#              id                                               text  \
# 0  X51007846290  NOEONF UNIHAKKA INTERNATIONAL SDN BHD 07 JUN 2...
# 1  X51005447859    PASARAYA BORONG PINTAR SDN BHD BR NO.: (1245...
# 2  X51005746203  / SUPER SEVEN CASH & TH. SDN BHD WALE 590 150-...
# 3  X51006329183  ’ TORE : \O SEMBOYAN TEGAS SDN BHD WE” NO.5 & ...
# 4  X51005442388  A03 (26 CONTENTO (JNO761170-4) 15, JALAN PERHA...
#
#                             company         date  \
# 0    UNIHAKKA INTERNATIONAL SDN BHD  20 JUN 2018
# 1    PASARAYA BORONG PINTAR SDN BHD     20180304
# 2  SUPER SEVEN CASH & CARRY SDN BHD     24-03-18
# 3                  GOLDEN KEY MAKER     24-03-18
# 4            MR. D.I.Y. (M) SDN BHD     24-03-18
#
#                                              address     total
# 0  12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAM...    RM8.20
# 1  NO 19-G& 19-1& 19-2 JALAN TASIK UTAMA 4, MEDAN...      3.20
# 2  NO. 1 JALAN EURO 1 OFF JALAN BATU TIGA SUNGAI ...  RM367.10
# 3  NO. 53, JALAN BESAR, 45600 BATANG BERJUNTAI SE...      6.00
# 4  NO. 17-G, JALAN SETIA INDAH (X) U13/X, SETIA A...     28.00

# %%
submit_path = '../data/output/model_nlp_dataset_submit'

# %%
# Create the directory for results
os.mkdir(path=submit_path)

# %%
for id, row in test_corpus.iterrows():
    data = {}
    data['company'] = row.company
    data['address'] = row.address
    data['total'] = row.total
    data['date'] = row.date
    
    add_to_file(data, submit_path, row.id+'.jpg')

# %% [markdown]
# Calculated!{"recall": 0.335014409221902, "precision": 0.335014409221902, "hmean": 0.335014409221902}%
